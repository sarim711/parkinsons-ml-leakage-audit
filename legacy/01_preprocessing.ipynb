# %%
# Allow importing from the 'src' folder
import sys
import os
sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.data.load_data import load_raw_data
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Load the data
df = load_raw_data()
df.head()
# Out:
# 📂 Loading data from: c:\Users\Sarim Shah\parkinsons\data/raw/parkinsons_updrs.data
# ✅ Data loaded successfully. Shape: (5875, 22)
#    subject#  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter(%)  \
# 0         1   72    0     5.6431       28.199       34.398    0.00662
# 1         1   72    0    12.6660       28.447       34.894    0.00300
# 2         1   72    0    19.6810       28.695       35.389    0.00481
# 3         1   72    0    25.6470       28.905       35.810    0.00528
# 4         1   72    0    33.6420       29.187       36.375    0.00335
#
#    Jitter(Abs)  Jitter:RAP  Jitter:PPQ5  ...  Shimmer(dB)  Shimmer:APQ3  \
# 0     0.000034     0.00401      0.00317  ...        0.230       0.01438
# 1     0.000017     0.00132      0.00150  ...        0.179       0.00994
# 2     0.000025     0.00205      0.00208  ...        0.181       0.00734
# 3     0.000027     0.00191      0.00264  ...        0.327       0.01106
# ...

# %%
total_samples = len(df)
print(total_samples)
# Out:
# 5875

# %%
samples_per_subject = df["subject#"].value_counts()
samples_per_subject.sort_index()
print(samples_per_subject)
# Out:
# subject#
# 29    168
# 35    165
# 41    165
# 34    161
# 7     161
# 24    156
# 5     156
# 6     156
# 9     152
# 8     150
# 42    150
# 1     149
# 38    149
# 10    148
# 2     145
# 3     144
# 25    144
# 17    144
# 15    143
# 39    143
# 40    142
# 37    140
# 16    138
# 11    138
# 23    138
# 4     137
# 14    136
# 33    135
# 28    134
# 20    134
# 26    130
# 31    130
# 27    129
# 19    129
# 36    129
# 18    126
# 30    126
# 21    123
# 13    112
# 22    112
# 12    107
# 32    101
# Name: count, dtype: int64

# %%
samples_per_subject.sort_index(ascending=True)

# %%
print(df.info())
print("\nMissing values:\n", df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5875 entries, 0 to 5874
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   subject#       5875 non-null   int64
#  1   age            5875 non-null   int64
#  2   sex            5875 non-null   int64
#  3   test_time      5875 non-null   float64
#  4   motor_UPDRS    5875 non-null   float64
#  5   total_UPDRS    5875 non-null   float64
#  6   Jitter(%)      5875 non-null   float64
#  7   Jitter(Abs)    5875 non-null   float64
#  8   Jitter:RAP     5875 non-null   float64
#  9   Jitter:PPQ5    5875 non-null   float64
#  10  Jitter:DDP     5875 non-null   float64
#  11  Shimmer        5875 non-null   float64
#  12  Shimmer(dB)    5875 non-null   float64
#  13  Shimmer:APQ3   5875 non-null   float64
#  14  Shimmer:APQ5   5875 non-null   float64
#  15  Shimmer:APQ11  5875 non-null   float64
#  16  Shimmer:DDA    5875 non-null   float64
# ...

# %%
sns.histplot(df['total_UPDRS'], kde=True)
plt.title("Distribution of Total UPDRS Scores")
plt.show()
